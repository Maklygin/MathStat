# %% [markdown]
# # Загрузка данных и поиск стран с минимум 30 респондентами в выборке.

# %%
# !pip install kaggle

# %%
# нужно загрузить kaggle.json
from google.colab import files
files.upload()
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# скачивание датасета
# !kaggle datasets download -d rtatman/speech-accent-archive

# разархивация
# !unzip 'speech-accent-archive.zip'

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("speakers_all.csv", header=0)

# %%
languages = df.groupby('country')['speakerid'].nunique().sort_values()

#страны для которых в базе есть более 30 записей
arr = np.array([[i,languages.to_dict()[i]] for i in languages.to_dict().keys() if languages.to_dict()[i]>=30])
for i in arr:
  print(i)
# Out:
# ['ethiopia' '31']
# ['russia' '31']
# ['italy' '32']
# ['germany' '32']
# ['australia' '33']
# ['saudi arabia' '33']
# ['poland' '34']
# ['turkey' '35']
# ['belgium' '36']
# ['brazil' '39']
# ['south korea' '51']
# ['canada' '54']
# ['india' '59']
# ['uk' '67']
# ['china' '88']
# ['usa' '393']

# %%
df_filter = df['country'].isin(arr[:,0])

# получим новую таблицу с нужными нам записями
df_new = df[df_filter]
df_new.info

# на первые три записи отсутствуют аудиофайлы, уберем их
df_new = df_new.drop(labels =[9,10,20] ,axis = 0) 
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1045 entries, 50 to 2170
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              1045 non-null   float64
#  1   age_onset        1045 non-null   float64
#  2   birthplace       1045 non-null   object
#  3   filename         1045 non-null   object
#  4   native_language  1045 non-null   object
#  5   sex              1045 non-null   object
#  6   speakerid        1045 non-null   int64
#  7   country          1045 non-null   object
#  8   file_missing?    1045 non-null   bool
#  9   Unnamed: 9       0 non-null      float64
#  10  Unnamed: 10      0 non-null      float64
#  11  Unnamed: 11      1 non-null      object
# dtypes: bool(1), float64(4), int64(1), object(6)
# memory usage: 99.0+ KB

# %% [markdown]
# # Получение суммы zero-crossing по каждой из записей.

# %%
# !pip install librosa
import librosa

# %%
df_new.rename(columns = {'Unnamed: 9' : 'zero_crossing'}, inplace = True)

j = 0
for i in df_new['filename'].values:
  x,sr = librosa.load('recordings/recordings/'+ i +'.mp3')

  zero_crossings = librosa.zero_crossings(x, pad=False)
  df_new.at[df_new.index[j],'zero-crossing'] = sum(zero_crossings)
  j+=1

# %%
df_new.sample(5)
# Out:
#        age  age_onset                    birthplace      filename  \
# 315   39.0       12.0                essen, belgium       dutch10
# 770   18.0        0.0          portland, maine, usa    english466
# 1627  26.0       24.0          juiz de fora, brazil  portuguese30
# 504   38.0        0.0  walton-on-thames, surrey, uk    english226
# 590   45.0        0.0      anaheim, california, usa    english303
#
#      native_language     sex  speakerid  country  file_missing?  \
# 315            dutch    male        913  belgium          False
# 770          english    male       1637      usa          False
# 1627      portuguese  female       1285   brazil          False
# 504          english    male        772       uk          False
# 590          english  female       1086      usa          False
#
#       zero-crossing  Unnamed: 10 Unnamed: 11
# 315         74358.0          NaN         NaN
# 770        108171.0          NaN         NaN
# 1627        39839.0          NaN         NaN
# 504         62212.0          NaN         NaN
# 590         85737.0          NaN         NaN

# %% [markdown]
# # ANOVA-анализ по аттрибутам родного языка, пола и возраста для уровня значимости 0.15.

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
lm = ols('zero_crossing ~ C(native_language) * C(sex) * age', data=df_new).fit()
table = sm.stats.anova_lm(lm, typ=1)
table
# Out:
#                                   df        sum_sq       mean_sq          F  \
# C(native_language)              55.0  2.626603e+11  4.775643e+09   6.723694
# C(sex)                           1.0  1.187253e+10  1.187253e+10  16.715496
# C(native_language):C(sex)       55.0  8.879766e+10  1.614503e+09   2.273081
# age                              1.0  1.205039e+10  1.205039e+10  16.965907
# C(native_language):age          55.0  6.603114e+10  1.200566e+09   1.690294
# C(sex):age                       1.0  1.223272e+08  1.223272e+08   0.172226
# C(native_language):C(sex):age   55.0  3.793214e+10  6.896753e+08   0.971004
# Residual                       914.0  6.491874e+11  7.102706e+08        NaN
#
#                                      PR(>F)
# C(native_language)             6.596541e-39
# C(sex)                         4.724826e-05
# C(native_language):C(sex)      8.381733e-07
# age                            4.150735e-05
# C(native_language):age         1.601797e-03
# C(sex):age                     6.782383e-01
# C(native_language):C(sex):age  5.362277e-01
# Residual                                NaN

# %%
table[table['PR(>F)'] < 0.15]
# Out:
#                              df        sum_sq       mean_sq          F  \
# C(native_language)         55.0  2.626603e+11  4.775643e+09   6.723694
# C(sex)                      1.0  1.187253e+10  1.187253e+10  16.715496
# C(native_language):C(sex)  55.0  8.879766e+10  1.614503e+09   2.273081
# age                         1.0  1.205039e+10  1.205039e+10  16.965907
# C(native_language):age     55.0  6.603114e+10  1.200566e+09   1.690294
#
#                                  PR(>F)
# C(native_language)         6.596541e-39
# C(sex)                     4.724826e-05
# C(native_language):C(sex)  8.381733e-07
# age                        4.150735e-05
# C(native_language):age     1.601797e-03
